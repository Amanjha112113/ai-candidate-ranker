# %% [markdown]
# # Candidate Ranking Pipeline (Optimized for Google Colab)
#
# This notebook will mount your Google Drive, install dependencies, and execute the precomputation and ranking phases.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Navigate to your project directory
# Update this path if your files are in a different directory in Google Drive
# %cd /content/drive/MyDrive/India_runs_data_and_ai_challenge
# %ls

# %%
# 3. Install required libraries
# !pip install sentence-transformers transformers rank_bm25 faiss-cpu

# %%
# 4. Run Precomputation Phase (GPU accelerated)
# !python precompute.py

# %%
# 5. Run Ranking Phase (GPU accelerated)
# !python rank.py

# %%
# 6. Preview Submission
import pandas as pd
try:
    df = pd.read_csv('submission.csv')
    display(df.head(20))
except Exception as e:
    print("Submission not generated yet.")
